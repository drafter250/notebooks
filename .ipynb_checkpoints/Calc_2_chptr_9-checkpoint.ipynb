# %% [markdown]
# Calc II chptr 9 Infinite Series
# ===============================
#
# ---------------------------------------------

# %%
def series(start, steps, function):
    """return a series from the given function start and sequence"""
    return [function(start + step) for step in steps]

def p_series(n):
    return 1/n**n

# %%
#range does not include endpoint
#series starting at n=1
p_result = series(1, range(10), p_series)
p_result
# Out:
# [1.0,
#  0.25,
#  0.037037037037037035,
#  0.00390625,
#  0.00032,
#  2.143347050754458e-05,
#  1.2142656789020123e-06,
#  5.960464477539063e-08,
#  2.581174791713197e-09,
#  1e-10]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(p_result)

# %%
def half_n(n):
    return 1/2**n

# %%
half_n_result = series(1, range(8), half_n)
half_n_result
# Out:
# [0.5, 0.25, 0.125, 0.0625, 0.03125, 0.015625, 0.0078125, 0.00390625]

# %%
plt.plot(range(1,9), half_n_result, 'o')

# %%
def nine_27(n):
    return 6 + (1/2)**n
nine_27_res = series(1, range(20), nine_27)
nine_27_res
# Out:
# [6.5,
#  6.25,
#  6.125,
#  6.0625,
#  6.03125,
#  6.015625,
#  6.0078125,
#  6.00390625,
#  6.001953125,
#  6.0009765625,
#  6.00048828125,
#  6.000244140625,
#  6.0001220703125,
#  6.00006103515625,
#  6.000030517578125,
#  6.0000152587890625,
#  6.000007629394531,
#  6.000003814697266,
#  6.000001907348633,
#  6.000000953674316]

# %%
plt.plot(range(1,21), nine_27_res, 'o')
